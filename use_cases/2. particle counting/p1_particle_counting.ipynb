# %% [markdown]
# # Particle Counting
#
# Please build an image processing workflow to determine the number of particles in the provided image and write down the explanation, finding or summary below the workflow.
#
# We are not looking for the optimal solution, but please try to get as close as you can in about 15 minutes.
#
# As you work through the image processing workflow, we encourage you to verbalize your thoughts, questions, concerns, or any points of uncertainty during the process.
#
# Once you have completed the analysis, kindly inform us.

# %%
{"nodes":[{"id":"1","position":{"x":662.1962851405622,"y":2.3884914658634493},"type":"read_image","data":{"displayLabel":"read image","description":"Reads a RGB or grayscale JPEG or PNG image. Optionally converts the image to the desired format.","inputs":[{"id":"in0","name":"path","type":"string","displayLabel":"file","description":"path of the JPEG or PNG image.","widget":{"type":"FileInputFromServer","extensions":[".jpg",".jpeg",".png"]},"defaultValue":"particle.png"},{"id":"in1","name":"mode","displayLabel":"mode","description":"mode - The read mode used for optionally converting the image. Default: GRAY.","defaultValue":"GRAY","widget":{"type":"Dropdown","options":["GRAY","RGB"]}}],"outputs":[{"id":"out0","name":"image","type":"image","displayLabel":"image","description":"The image read from the file.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}},"connections":1}],"specName":"read_image"},"measured":{"width":302,"height":296},"selected":false,"dragging":false},{"id":"3","position":{"x":1633.78765687751,"y":-3.320576054216872},"type":"read_image","data":{"displayLabel":"remove small holes","description":"Remove small holes (connected regions of background) within foreground objects in a binary image. It fills in small \"holes\" or gaps inside objects that you might want to close.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1},{"id":"in1","name":"area_threshold","displayLabel":"area threshold","description":"The maximum area, in pixels, of a contiguous hole that will be filled.","defaultValue":76,"widget":{"type":"Number","min":0,"step":1}}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The input image with small holes within connected components removed.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}},"connections":1}],"specName":"remove small holes"},"measured":{"width":302,"height":292},"selected":false,"dragging":false},{"id":"4","position":{"x":1311.9662776104417,"y":-5.983138805220879},"type":"read_image","data":{"displayLabel":"remove small objects","description":"Remove small objects (connected regions of foreground) in a binary image. It removes small, isolated objects that are smaller than a specified threshold.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1},{"id":"in1","name":"min_size","displayLabel":"min size","description":"Objects smaller than this size will be removed","defaultValue":64,"widget":{"type":"Number","min":0,"step":1}}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The input image with small connected components removed.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}},"connections":1}],"specName":"remove small objects"},"measured":{"width":302,"height":292},"selected":false,"dragging":false},{"id":"5","position":{"x":1956.3791352911649,"y":-0.6944653614458147},"type":"read_image","data":{"displayLabel":"split touching objects","description":"split touching objects (connected regions of foreground) in a binary image. It splits objects that are touching or overlapping.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1},{"id":"in1","name":"sigma","displayLabel":"sigma","description":"The standard deviation of the Gaussian kernel used for smoothing the image.","defaultValue":3,"widget":{"type":"Number","min":0,"step":1}}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The input image with small connected components removed.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}},"connections":1}],"specName":"split touching objects"},"measured":{"width":302,"height":292},"selected":false,"dragging":false},{"id":"7","position":{"x":2279.475056475904,"y":7.888127510040114},"type":"read_image","data":{"displayLabel":"binary erosion","description":"Erosion sets a pixel at to the minimum over all pixels in the neighborhood centered at. Erosion shrinks bright regions and enlarges dark regions.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"binary image","description":"The eroded output image.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}},"connections":2}],"specName":"binary erosion"},"measured":{"width":302,"height":262},"selected":false,"dragging":false},{"id":"8","position":{"x":2652.41467745984,"y":258.65276731927713},"type":"read_image","data":{"displayLabel":"binary erosion","description":"Erosion sets a pixel at to the minimum over all pixels in the neighborhood centered at. Erosion shrinks bright regions and enlarges dark regions.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"binary image","description":"The eroded output image.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}},"connections":1}],"specName":"binary erosion"},"measured":{"width":302,"height":262},"selected":false,"dragging":false},{"id":"12","position":{"x":3305.7599344858154,"y":326.0381502798111},"type":"read_image","data":{"displayLabel":"summary","description":"Extract properties (index, pixel count, position) of each segments after applying segmentation algorithms.","inputs":[{"id":"in0","name":"segments","type":"segments","displayLabel":"segments","description":"The segments of the image after applying segmentation algorithms.","connections":1}],"outputs":[{"id":"out0","name":"summary","type":"summary","displayLabel":"summary","description":"The region properties of the labeled regions."}],"specName":"regionprops"},"measured":{"width":302,"height":103},"selected":true,"dragging":false},{"id":"13","position":{"x":2972.6021979880506,"y":197.49924757060955},"type":"read_image","data":{"displayLabel":"watershed segmentation","description":"Separating overlapping or touching objects in an image into distinct regions or segments.","inputs":[{"id":"in0","name":"image","type":["binary image","image"],"displayLabel":"image (binary, gray, rgb)","description":"The interesting objects are assumed to be brighter than the background.","connections":1},{"id":"in1","name":"underlay_image","type":["image"],"displayLabel":"underlay image (shape as image)","description":"Image used as underlay for segments. It should have the same shape as image (first parameter), optionally with an additional RGB (channels) axis. If is an RGB image, it is converted to grayscale.","defaultValue":"None"},{"id":"in2","name":"granularity","displayLabel":"granularity","description":"The granularity parameter for watershed segmentation.","defaultValue":0.1,"widget":{"type":"Number","step":0.1}}],"outputs":[{"id":"out0","name":"segments","type":"segments","displayLabel":"segments","description":"The segmentes produced by watershed algorithm.","connections":1},{"id":"out1","name":"vis","type":"image","description":"The visualization of segmentes.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":false,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}}}],"specName":"watershed"},"measured":{"width":302,"height":340},"selected":false,"dragging":false},{"id":"14","position":{"x":2654.7961834813977,"y":-116.26515144704769},"type":"read_image","data":{"displayLabel":"watershed segmentation","description":"Separating overlapping or touching objects in an image into distinct regions or segments.","inputs":[{"id":"in0","name":"image","type":["binary image","image"],"displayLabel":"image (binary, gray, rgb)","description":"The interesting objects are assumed to be brighter than the background.","connections":1},{"id":"in1","name":"underlay_image","type":["image"],"displayLabel":"underlay image (shape as image)","description":"Image used as underlay for segments. It should have the same shape as image (first parameter), optionally with an additional RGB (channels) axis. If is an RGB image, it is converted to grayscale.","defaultValue":"None"},{"id":"in2","name":"granularity","displayLabel":"granularity","description":"The granularity parameter for watershed segmentation.","defaultValue":0.1,"widget":{"type":"Number","step":0.1}}],"outputs":[{"id":"out0","name":"segments","type":"segments","displayLabel":"segments","description":"The segmentes produced by watershed algorithm."},{"id":"out1","name":"vis","type":"image","description":"The visualization of segmentes.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":false,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":601,"height":365}}}}],"specName":"watershed"},"measured":{"width":302,"height":340},"selected":false,"dragging":false},{"id":"15","position":{"x":985.2062813755022,"y":-29.68068524096385},"type":"read_image","data":{"displayLabel":"threshold","description":"Generates a binary image by applying thresholding to the input image using specified upper and lower bounds. Pixels with values within the range are set to 1, while those outside the range are set to 0.","inputs":[{"id":"in0","name":"image","type":"image","displayLabel":"grayscale image","description":"The input image for thresholding.","connections":1},{"id":"in1","name":"range","type":"tuple2","displayLabel":"Range","description":"The threshold bounds for binarization (lower, upper).","defaultValue":[0.31,0.91],"widget":{"type":"HistogramRange","min":0,"max":1,"step":0.01,"value":{"histogram":{"type":"grayscale","data":[0.2726335681154441,0.10925957739220066,0.12970280020615016,0.15220752448032984,0,0.1774609173681498,0.18605050678577564,0.21181927503865317,0.21714482047758119,0.24394433946057378,0.26095172650747295,0,0.28672049476035044,0.3193609345473286,0.33293248582717744,0.3631678405772204,0.3867033155815152,0.3927160281738533,0,0.43463322453186737,0.4145335852946229,0.4468304415048961,0.4591994502662773,0.4738017522762412,0.4911527228998454,0,1,0,0.5359903796598523,0.522247036591651,0.5078165263700395,0.6162171448204776,0.5062704002748669,0,0.5153753650575502,0.5227624119567085,0.9945026627727195,0,0.48891942965126267,0,0.4537021130389967,0.4523277787321766,0.43549218347362995,0.36797801065109087,0.3502834564507816,0.31833018381721356,0,0.26833877340663115,0.45799690774780966,0.19000171791788353,0,0.16784057722040888,0.15203573269197732,0.13365401133825802,0,0.10101357155127985,0.1937811372616389,0,0.08486514344614328,0.08074214052568288,0.07369867720322969,0,0.06991925785947432,0.0625322109603161,0.05411441333104278,0.11561587356124377,0,0,0.05617591479127298,0.04930424325717231,0.05308366260092767,0.052224703659165095,0.052224703659165095,0.053770829754337744,0,0.05961175055832331,0.05291187081257516,0.054286205119395296,0.05686308194468304,0.04758632537364714,0.05961175055832331,0.06304758632537365,0,0.06201683559525855,0.06236041917196358,0.055660539426215426,0.06304758632537365,0.07043463322453186,0.06648342209242399,0,0.06923209070606424,0.07507301151004982,0.0738704689915822,0.08074214052568288,0.08280364