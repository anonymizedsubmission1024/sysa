# %%
{"nodes":[{"id":"1","position":{"x":-680.1136381348263,"y":-846.1419996586063},"type":"read_image","data":{"displayLabel":"batch process","description":"Process multiple images from a folder.","inputs":[{"id":"in0","name":"folder_path","type":"string","displayLabel":"folder","description":"Select a folder containing images ('.jpg', '.jpeg', '.png', '.JPG', '.JPEG', '.PNG').","widget":{"type":"FileInputFromServer","extensions":[]},"defaultValue":"confocal_2803"},{"id":"in1","name":"image_gallery","type":"string[]","displayLabel":"gallery","description":"Output selected images to process","defaultValue":["image1.png","image1_6.png","image2.png","image2_5.png","image3-4.png","image3.png","image4.png","image5.png","imagen.png"],"widget":{"type":"ImageGallery","value":{"type":"folder","images":[{"imageUrl":"data:image/png;base64,...","filename":"image1.png","dimensions":{"width":1024,"height":1024}},{"imageUrl":"data:image/png;base64,...","filename":"image1_6.png","dimensions":{"width":1024,"height":1024}},{"imageUrl":"data:image/png;base64,...","filename":"image2.png","dimensions":{"width":1024,"height":1024}},{"imageUrl":"data:image/png;base64,...","filename":"image2_5.png","dimensions":{"width":1024,"height":1024}},{"imageUrl":"data:image/png;base64,...","filename":"image3-4.png","dimensions":{"width":1024,"height":1024}},{"imageUrl":"data:image/png;base64,...","filename":"image3.png","dimensions":{"width":1024,"height":1024}},{"imageUrl":"data:image/png;base64,...","filename":"image4.png","dimensions":{"width":1024,"height":1024}},{"imageUrl":"data:image/png;base64,...","filename":"image5.png","dimensions":{"width":1024,"height":1024}},{"imageUrl":"data:image/png;base64,...","filename":"imagen.png","dimensions":{"width":1936,"height":1022}}]}}}],"outputs":[{"id":"out0","name":"each selected image","type":"image","displayLabel":"processed image","description":"The processed image.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":false,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":1936,"height":1022}}},"connections":1},{"id":"out1","name":"batch_results","type":"dataframe","displayLabel":"batch results","description":"The processed images.","connections":1}],"specName":"batch_process"},"measured":{"width":302,"height":482},"selected":false,"dragging":false},{"id":"2","position":{"x":-351.6070627485835,"y":-818.5324823880275},"type":"read_image","data":{"displayLabel":"auto binarize","description":"Automatically binarize the input image using Otsu thresholding.","inputs":[{"id":"in0","name":"image","type":"image","displayLabel":"image","description":"The input image to be binarized.","connections":1}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The binarized output image.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":true,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":1936,"height":1022}}},"connections":1}],"specName":"auto binarize"},"measured":{"width":302,"height":262},"selected":false,"dragging":false},{"id":"3","position":{"x":-349.9963232089331,"y":-512.0216281100472},"type":"read_image","data":{"displayLabel":"save to csv","description":"Save the input data to a CSV file.","inputs":[{"id":"in0","name":"data","type":["summary","dataframe"],"displayLabel":"data","description":"The data(including summary and ...) to save as a CSV.","connections":1},{"id":"in1","name":"name","type":"string","displayLabel":"name","description":"CSV File to save the data.","defaultValue":"export.csv","widget":{"type":"String","placeholder":"for example: export.csv"}},{"id":"in2","name":"destination","type":"string","displayLabel":"destination","description":"The folder where the file will be saved.","widget":{"type":"FileInputFromServer","extensions":[]},"defaultValue":"results"}],"outputs":[],"specName":"save_to_csv"},"measured":{"width":302,"height":139},"selected":false,"dragging":false},{"id":"4","position":{"x":-24.245149005636193,"y":-819.7520041867234},"type":"read_image","data":{"displayLabel":"invert","description":"In a binary image, each pixel is either black (0) or white (1). The invert operation switches these values: all black pixels become white, and all white pixels become black.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"The input image to be inverted.","connections":1}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"binary image","description":"The inverted output image.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":true,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":1936,"height":1022}}},"connections":1}],"specName":"Invert"},"measured":{"width":302,"height":262},"selected":false,"dragging":false},{"id":"5","position":{"x":308.48392868670123,"y":-843.7468279909498},"type":"read_image","data":{"displayLabel":"watershed segmentation","description":"Separating overlapping or touching objects in an image into distinct regions or segments.","inputs":[{"id":"in0","name":"image","type":["binary image","image"],"displayLabel":"image (binary, gray, rgb)","description":"The interesting objects are assumed to be brighter than the background.","connections":1},{"id":"in1","name":"underlay_image","type":["image"],"displayLabel":"underlay image (shape as image)","description":"Image used as underlay for segments. It should have the same shape as image (first parameter), optionally with an additional RGB (channels) axis. If is an RGB image, it is converted to grayscale.","defaultValue":"None"},{"id":"in2","name":"granularity","displayLabel":"granularity","description":"The granularity parameter for watershed segmentation.","defaultValue":0.1,"widget":{"type":"Number","step":0.1}}],"outputs":[{"id":"out0","name":"segments","type":"segments","displayLabel":"segments","description":"The segmentes produced by watershed algorithm.","connections":1},{"id":"out1","name":"vis","type":"image","description":"The visualization of segmentes.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":false,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":1936,"height":1022}}}}],"specName":"watershed"},"measured":{"width":302,"height":340},"selected":false,"dragging":false},{"id":"6","position":{"x":635.543530197744,"y":-793.7631920037885},"type":"read_image","data":{"displayLabel":"segmentes size","description":"Extract size of each segments after applying segmentation algorithms.","inputs":[{"id":"in0","name":"segments","type":"segments","displayLabel":"segments","description":"The segments of the image after applying segmentation algorithms.","connections":1}],"outputs":[{"id":"out0","name":"sizes","type":"list","displayLabel":"sizes","description":"The size of each segments.","connections":1}],"specName":"regionsize"},"measured":{"width":302,"height":103},"selected":false,"dragging":false},{"id":"7","position":{"x":643.1876022855758,"y":-631.2013937760786},"type":"read_image","data":{"displayLabel":"collect result per batch","description":"Output the result at each batch.","inputs":[{"id":"in0","name":"result","type":"*","displayLabel":"result","description":"result per batch.","connections":1}],"outputs":[],"specName":"collect_batch_results"},"measured":{"width":302,"height":79},"selected":false,"dragging":false}],"edges":[{"source":"1","sourceHandle":"out0","target":"2","targetHandle":"in0","id":"1","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"1","sourceHandle":"out1","target":"3","targetHandle":"in0","id":"2","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"2","sourceHandle":"out0","target":"4","targetHandle":"in0","id":"3","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"4","sourceHandle":"out0","target":"5","targetHandle":"in0","id":"4","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"5","sourceHandle":"out0","target":"6","targetHandle":"in0","id":"5","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"6","sourceHandle":"out0","target":"7","targetHandle":"in0","id":"6","markerEnd":{"type":"arrow","width":30,"height":30}}]}
