# %% [markdown]
# # Grain Size Measurement
#
# Please build an image processing workflow to determine the size of individual grain in the provided image and write down the explanation, finding or summary below the workflow.
#
# We are not looking for the optimal solution, but please try to get as close as you can in about 15 minutes.
#
# As you work through the image processing workflow, we encourage you to verbalize your thoughts, questions, concerns, or any points of uncertainty during the process.
#
# Once you have completed the analysis, kindly inform us.

# %%
{"nodes":[{"id":"1","position":{"x":191.91450488767128,"y":-618.1262247194575},"type":"read_image","data":{"displayLabel":"read image","description":"Reads a RGB or grayscale JPEG or PNG image. Optionally converts the image to the desired format.","inputs":[{"id":"in0","name":"path","type":"string","displayLabel":"file","description":"path of the JPEG or PNG image.","widget":{"type":"FileInputFromServer","extensions":[".jpg",".jpeg",".png"]},"defaultValue":"grain.png"},{"id":"in1","name":"mode","displayLabel":"mode","description":"mode - The read mode used for optionally converting the image. Default: GRAY.","defaultValue":"GRAY","widget":{"type":"Dropdown","options":["GRAY","RGB"]}}],"outputs":[{"id":"out0","name":"image","type":"image","displayLabel":"image","description":"The image read from the file.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"read_image"},"measured":{"width":302,"height":296},"selected":false,"dragging":false},{"id":"6","position":{"x":1003.8750244578998,"y":-583.2931512735139},"type":"read_image","data":{"displayLabel":"remove small objects","description":"Remove small objects (connected regions of foreground) in a binary image. It removes small, isolated objects that are smaller than a specified threshold.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1},{"id":"in1","name":"min_size","displayLabel":"min size","description":"Objects smaller than this size will be removed","defaultValue":72,"widget":{"type":"Number","min":0,"step":1}}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The input image with small connected components removed.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"remove small objects"},"measured":{"width":302,"height":292},"selected":false,"dragging":false},{"id":"17","position":{"x":1405.81906392758,"y":-562.0971595415119},"type":"read_image","data":{"displayLabel":"invert","description":"In a binary image, each pixel is either black (0) or white (1). The invert operation switches these values: all black pixels become white, and all white pixels become black.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"The input image to be inverted.","connections":1}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"binary image","description":"The inverted output image.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"Invert"},"measured":{"width":302,"height":262},"selected":true,"dragging":false},{"id":"18","position":{"x":139.11916642287062,"y":-267.30499754647514},"type":"read_image","data":{"displayLabel":"split touching objects","description":"split touching objects (connected regions of foreground) in a binary image. It splits objects that are touching or overlapping.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1},{"id":"in1","name":"sigma","displayLabel":"sigma","description":"The standard deviation of the Gaussian kernel used for smoothing the image.","defaultValue":4,"widget":{"type":"Number","min":0,"step":1}}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The input image with small connected components removed.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"split touching objects"},"measured":{"width":302,"height":292},"selected":false,"dragging":false},{"id":"19","position":{"x":463.79196320069025,"y":-263.1072510054096},"type":"read_image","data":{"displayLabel":"remove small objects","description":"Remove small objects (connected regions of foreground) in a binary image. It removes small, isolated objects that are smaller than a specified threshold.","inputs":[{"id":"in0","name":"image","type":"binary image","displayLabel":"binary image","description":"Binary input image","connections":1},{"id":"in1","name":"min_size","displayLabel":"min size","description":"Objects smaller than this size will be removed","defaultValue":68,"widget":{"type":"Number","min":0,"step":1}}],"outputs":[{"id":"out0","name":"image","type":"binary image","displayLabel":"image","description":"The input image with small connected components removed.","widget":{"type":"ImageViewer","value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"remove small objects"},"measured":{"width":302,"height":292},"selected":false,"dragging":false},{"id":"21","position":{"x":1146.5869198839425,"y":-258.96788355946},"type":"read_image","data":{"displayLabel":"summary","description":"Extract properties (index, pixel count, position) of each segments after applying segmentation algorithms.","inputs":[{"id":"in0","name":"segments","type":"segments","displayLabel":"segments","description":"The segments of the image after applying segmentation algorithms.","connections":1}],"outputs":[{"id":"out0","name":"summary","type":"summary","displayLabel":"summary","description":"The region properties of the labeled regions.","connections":1}],"specName":"regionprops"},"measured":{"width":302,"height":103},"selected":false,"dragging":false},{"id":"22","position":{"x":1150.4418547065854,"y":-106.74669118748638},"type":"read_image","data":{"displayLabel":"save image","description":"Save the image data to a file.","inputs":[{"id":"in0","name":"image","type":"image","displayLabel":"image","description":"The image to save.","connections":1},{"id":"in1","name":"name","type":"string","displayLabel":"name","description":"PNG File to save the image.","defaultValue":"result.png","widget":{"type":"String","placeholder":"for example: image.png"}},{"id":"in2","name":"destination","type":"string","displayLabel":"destination","description":"The folder where the image file will be saved.","widget":{"type":"FileInputFromServer","extensions":[]},"defaultValue":""}],"outputs":[],"specName":"save_image"},"measured":{"width":302,"height":139},"selected":false,"dragging":false},{"id":"23","position":{"x":1503.6745222794443,"y":-198.79601510786318},"type":"read_image","data":{"displayLabel":"save to csv","description":"Save the input data to a CSV file.","inputs":[{"id":"in0","name":"data","type":"summary","displayLabel":"data","description":"The data(including summary and ...) to save as a CSV.","connections":1},{"id":"in1","name":"name","type":"string","displayLabel":"name","description":"CSV File to save the data.","defaultValue":"export.csv","widget":{"type":"String","placeholder":"for example: export.csv"}},{"id":"in2","name":"destination","type":"string","displayLabel":"destination","description":"The folder where the file will be saved.","widget":{"type":"FileInputFromServer","extensions":[]},"defaultValue":""}],"outputs":[],"specName":"save_to_csv"},"measured":{"width":302,"height":139},"selected":false,"dragging":false},{"id":"24","position":{"x":595.80408309154,"y":-653.4557897869219},"type":"read_image","data":{"displayLabel":"threshold","description":"Generates a binary image by applying thresholding to the input image using specified upper and lower bounds. Pixels with values within the range are set to 1, while those outside the range are set to 0.","inputs":[{"id":"in0","name":"image","type":"image","displayLabel":"grayscale image","description":"The input image for thresholding.","connections":1},{"id":"in1","name":"range","type":"tuple2","displayLabel":"Range","description":"The threshold bounds for binarization (lower, upper).","defaultValue":[0.06,0.71],"widget":{"type":"HistogramRange","min":0,"max":1,"step":0.01,"value":{"histogram":{"type":"grayscale","data":[0.011215477358755083,0.0014720314033366045,0.0011916444693677274,0.001331837936352166,0.0012617412028599468,0.0014019346698443853,0.0017524183373054817,0.001612224870321043,0.0014720314033366045,0.0011916444693677274,0.001331837936352166,0.00189261180428992,0.0011215477358755082,0.0014720314033366045,0.0016823216038132623,0.0016823216038132623,0.0015421281368288237,0.0014720314033366045,0.001331837936352166,0.0018225150707977008,0.00189261180428992,0.002102902004766578,0.0014720314033366045,0.0024533856722276743,0.003715126875087621,0,0.004345997476517594,0,0.001612224870321043,0.0015421281368288237,0.0025935791392121127,0.001962708537782139,0.004345997476517594,0,0.0025234824057198935,0.0018225150707977008,
0.42163185195569886,0.8712323005747932,0,0.4457451282770223,0.45829244357212956,0.4864012337025095,0.49537361558951354,1,0,0.49943922613206226,0.4890649095752138,0.4847189120986962,0.47322304780597224,0.9449039674751156,0,0.4748352726762933,0.46817608299453245,0.45759147623720736,0.43361839338286834,0.41272956680218703,0.38398990607037714,0.36891910836955,0.34662834711902424,0.334081031823917,0.3140333660451423,0.2988223748773307,0.2826300294406281,0.2690312631431375,0.2477919528949951,0.41917846628347116,0,0.1877891490256554,0.17194728725641384,0.15848871442590776,0.15961026216178326,0.14510023832889388,0.2705733912799664,0,0.1284172157577457,0.11860367306883499,0.12722557128837797,0.5293004345997476]}}}}],"outputs":[{"id":"out0","name":"image","type":"binary image","description":"The resulting binary image after thresholding.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":true,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"threshold"},"measured":{"width":302,"height":370},"selected":false,"dragging":false},{"id":"25","position":{"x":798.0129701023008,"y":-271.73809972368167},"type":"read_image","data":{"displayLabel":"watershed segmentation","description":"Separating overlapping or touching objects in an image into distinct regions or segments.","inputs":[{"id":"in0","name":"image","type":["binary image","image"],"displayLabel":"image (binary, gray, rgb)","description":"The interesting objects are assumed to be brighter than the background.","connections":1},{"id":"in1","name":"underlay_image","type":["image"],"displayLabel":"underlay image (shape as image)","description":"Image used as underlay for segments. It should have the same shape as image (first parameter), optionally with an additional RGB (channels) axis. If is an RGB image, it is converted to grayscale.","defaultValue":"None"},{"id":"in2","name":"granularity","displayLabel":"granularity","description":"The granularity parameter for watershed segmentation.","defaultValue":0.1,"widget":{"type":"Number","step":0.1}}],"outputs":[{"id":"out0","name":"segments","type":"segments","displayLabel":"segments","description":"The segmentes produced by watershed algorithm.","connections":1},{"id":"out1","name":"vis","type":"image","description":"The visualization of segmentes.","widget":{"type":"ImageViewer","showDiff":false,"isBinary":false,"value":{"imageUrl":"data:image/png;base64,...","dimensions":{"width":698,"height":472}}},"connections":1}],"specName":"watershed"},"measured":{"width":302,"height":340},"selected":false,"dragging":false}],"edges":[{"source":"6","sourceHandle":"out0","target":"17","targetHandle":"in0","id":"24","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"17","sourceHandle":"out0","target":"18","targetHandle":"in0","id":"25","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"18","sourceHandle":"out0","target":"19","targetHandle":"in0","id":"26","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"21","sourceHandle":"out0","target":"23","targetHandle":"in0","id":"30","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"1","sourceHandle":"out0","target":"24","targetHandle":"in0","id":"31","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"24","sourceHandle":"out0","target":"6","targetHandle":"in0","id":"32","markerEnd":{"type":"arrow","width":30,"height":30},"selected":false},{"source":"19","sourceHandle":"out0","target":"25","targetHandle":"in0","id":"33","markerEnd":{"type":"arrow","width":30,"height":30}},{"source":"25","sourceHandle":"out0","target":"21","targetHandle":"in0","id":"34","markerEnd":{"type":"arrow","width":30,"height":30}},{"source":"25","sourceHandle":"out1","target":"22","targetHandle":"in0","id":"35","markerEnd":{"type":"arrow","width":30,"height":30}}]}
# Out:
# Number of segments: 155
# Average segments pixels size: 1904.4064516129033
